# %% [markdown]
# Absolutely! Here are some hands-on **Python exercises** to test your knowledge of the topics from Lecture 4: libraries, random, statistics, command-line arguments, slices, packages, APIs, and creating your own modules.
#
# ---
#
# ## 🔢 Section 1: Built-In Libraries (`random`, `statistics`)
#
# ### 1.1 Coin Toss Simulator
#
# Write a program that simulates 100 coin tosses and counts how many times you get heads.
#
# ```python
# # Starter: import random
# ```
#
# ---
#
# ### 1.2 Dice Roller
#
# Create a program that rolls two six-sided dice 10 times and prints the sum of each roll.
#
# ```python
# # Use random.randint
# ```
#
# ---
#
# ### 1.3 Calculate Mean and Median
#
# Use the `statistics` module to calculate the **mean** and **median** of a list of numbers you define in your code.
#
# ```python
# # List: [7, 13, 42, 8, 19]
# ```
#
# ---
#
# ## 💻 Section 2: Command-Line Arguments
#
# ### 2.1 Greeting Script
#
# Write a program `greet.py` that says hello to each name provided in the command line:
#
# ```bash
# python greet.py Alice Bob Charlie
# ```
#
# Should print:
#
# ```
# hello, Alice
# hello, Bob
# hello, Charlie
# ```
#
# ---
#
# ### 2.2 Average Calculator via CLI
#
# Write `cli_average.py` that accepts numbers from the command line and prints the average:
#
# ```bash
# python cli_average.py 10 20 30 40
# ```
#
# Should print:
#
# ```
# Average: 25.0
# ```
#
# ---
#
# ## 🧩 Section 3: Slices
#
# ### 3.1 Name Slicer
#
# Write a program that prints all names **except** the first one from the list below using slicing:
#
# ```python
# names = ["Intro", "Alice", "Bob", "Charlie", "Denise"]
# ```
#
# ---
#
# ## 📦 Section 4: Packages & pip
#
# ### 4.1 Install and Use `cowsay`
#
# After installing `cowsay`, write a program that uses a cow to say "Coding is fun!"
#
# ```bash
# pip install cowsay
# ```
#
# ```python
# # Import cowsay and try cowsay.tux("Coding is fun!")
# ```
#
# ---
#
# ## 🌐 Section 5: APIs & JSON
#
# ### 5.1 iTunes Lookup
#
# Modify the iTunes API example to return **the track name and artist** for any search term provided by the user:
#
# ```bash
# python itunes.py adele
# ```
#
# Should print:
#
# ```
# Track: Hello
# Artist: Adele
# ```
#
# (Hint: response.json()\['results']\[0]\['trackName'])
#
# ---
#
# ## 🧰 Bonus Challenge: Make Your Own Module
#
# ### 6.1 Create and Use a Custom Library
#
# 1. Create a file called `mytools.py` with a function `square(n)` that returns `n * n`.
# 2. In another file `main.py`, import your module and use it to square a number from the command line.
