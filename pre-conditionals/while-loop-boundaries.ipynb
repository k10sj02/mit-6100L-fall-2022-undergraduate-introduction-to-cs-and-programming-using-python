# %% [markdown]
# # 🔄 Practice: Setting Up `while` Loop Conditions
#
# ### 1. **Counting from 1 to 10 (inclusive)**
# Start at 1, stop at 10, increment by 1.
# ```python
# i = 1
# while i <= 10:
# ```
#
# ### 2. **Counting from 10 down to 1 (inclusive)**
# Start at 10, stop at 1, decrement by 1.
# ```python
# i = 10
# while i >= 1:
# ```
#
# ### 3. **Prompting the user for input until they enter 'exit'**
# Start with an empty string, keep prompting until the user types "exit".
# ```python
# user_input = ""
# while user_input != "exit":
# ```
#
# ### 4. **Print all odd numbers between 1 and 20**
# Start at 1, increment by 2 each time, stop before or at 20.
# ```python
# i = 1
# while i <= 20:
# ```
#
# ### 5. **Sum all numbers from 1 to 100**
# Start at 1, add each number to the sum, stop after reaching 100.
# ```python
# i = 1
# total_sum = 0
# while i <= 100:
# ```
#
# ### 6. **Find the first number greater than 1000 that is divisible by both 5 and 7**
# Start at a number greater than 1000, check divisibility, increment by 1 until you find the number.
# ```python
# i = 1001
# while i % 5 != 0 or i % 7 != 0:
# ```
#
# ### 7. **Display the characters in a string (one at a time)**
# Start at index 0, print each character, stop after reaching the last character.
# ```python
# index = 0
# while index < len(my_string):
# ```
#
# ### 8. **Double a number until it exceeds 1000**
# Start with any number (e.g., 5), keep doubling it until it exceeds 1000.
# ```python
# num = 5
# while num <= 1000:
# ```
#
# ---
#
# 📝 **Task**
# - Now, try completing the body of each loop.
# ```
